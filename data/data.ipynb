# %% [markdown]
# # Data: TransferMarkt

# %%
import pandas as pd

# %%
appearances = pd.read_csv('./archive/appearances.csv')
competition = pd.read_csv('./archive/competitions.csv')

# %%
appearances[appearances.competition_id.isin(competition[
            (competition.type == 'domestic_league')
            & (competition.sub_type == 'first_tier')
            & (competition.country_name.isin(['England', 'France', 'Germany', 'Italy', 'Spain'])) 
].competition_id.values)]
# Out:
#           appearance_id  game_id  player_id  player_club_id  \
# 4345     2229837_108830  2229837     108830             415
# 4346     2229837_113707  2229837     113707             969
# 4347     2229837_126767  2229837     126767             415
# 4348     2229837_126796  2229837     126796             415
# 4349     2229837_127032  2229837     127032             415
# ...                 ...      ...        ...             ...
# 1556770  4112992_716276  4112992     716276            1050
# 1556771   4112992_74869  4112992      74869            1050
# 1556772   4112992_76467  4112992      76467            1050
# 1556773   4112992_80293  4112992      80293            1050
# 1556774  4112992_834764  4112992     834764            1049
#
#          player_current_club_id        date       player_name competition_id  \
# 4345                       3205  2012-08-10   Aymen Abdennour            FR1
# 4346                       1082  2012-08-10      Rémy Cabella            FR1
# ...

# %%
competition.sub_type.unique()
# Out:
# array(['domestic_cup', 'domestic_super_cup', 'uefa_super_cup',
#        'first_tier', 'europa_league', 'europa_league_qualifying',
#        'league_cup', 'uefa_europa_conference_league_qualifiers',
#        'uefa_champions_league', 'fifa_club_world_cup',
#        'uefa_champions_league_qualifying'], dtype=object)
